# %%
import pandas as pd

# %%
advanced_df = pd.read_csv("advanced_stats_2013_to_2018_updated.csv")
advanced_df.head()
# Out:
#    NBA_Season         Player Pos  Age   Tm   G    MP   PER  TS_Perc   3PAr  \
# 0        2013    Jeff Adrien  PF   26  CHA  52   713  13.4    0.493  0.012
# 1        2013  Arron Afflalo  SF   27  ORL  64  2307  13.0    0.527  0.265
# 2        2013   Josh Akognon  PG   26  DAL   3     9  15.3    0.625  0.500
# 3        2013   Cole Aldrich   C   24  TOT  45   388  11.1    0.563  0.000
# 4        2013   Cole Aldrich   C   24  HOU  30   213   7.3    0.532  0.000
#
#    ...   TOV_Perc  USG_Perc  OWS  DWS   WS  WS_per_48  OBPM  DBPM  BPM  VORP
# 0  ...       13.1      15.6  0.5  0.4  1.0      0.064  -3.0  -0.2 -3.3  -0.2
# 1  ...       12.1      22.5  1.5  0.5  2.0      0.042  -0.3  -2.0 -2.3  -0.2
# 2  ...        0.0      20.3  0.0  0.0  0.0      0.196   4.7  -4.9 -0.2   0.0
# 3  ...       20.6      12.7  0.1  0.4  0.6      0.070  -4.8   0.7 -4.0  -0.2
# 4  ...       23.0      12.5 -0.1  0.3  0.2      0.038  -5.7   1.0 -4.8  -0.1
#
# [5 rows x 27 columns]

# %%
draft_df = pd.read_csv("draft_data_2013_to_2017_updated.csv")
draft_df.head()
# Out:
#    Draft_Yr  Pk   Tm           Player                          College  Yrs  \
# 0      2013   1  CLE  Anthony Bennett  University of Nevada, Las Vegas    4
# 1      2013   2  ORL   Victor Oladipo               Indiana University    6
# 2      2013   3  WAS      Otto Porter            Georgetown University    6
# 3      2013   4  CHA      Cody Zeller               Indiana University    6
# 4      2013   5  PHO         Alex Len           University of Maryland    6
#
#      G     MP   PTS   TRB  ...   3P_Perc  FT_Perc  MP_per_G  PTS_per_G  \
# 0  151   1905   658   472  ...     0.261    0.670      1905        4.4
# 1  369  12303  6419  1674  ...     0.354    0.797     12303       17.4
# 2  345   9123  3623  1687  ...     0.404    0.789      9123       10.5
# 3  315   7097  2496  1771  ...     0.294    0.734      7097        7.9
# 4  337   6704  2437  2183  ...     0.250    0.707      6704        7.2
#
#    TRB_per_G  AST_per_G    WS  WS_per_48  BPM  VORP
# ...

# %%
draft_df.columns.tolist()
# Out:
# ['Draft_Yr',
#  'Pk',
#  'Tm',
#  'Player',
#  'College',
#  'Yrs',
#  'G',
#  'MP',
#  'PTS',
#  'TRB',
#  'AST',
#  'FG_Perc',
#  '3P_Perc',
#  'FT_Perc',
#  'MP_per_G',
#  'PTS_per_G',
#  'TRB_per_G',
#  'AST_per_G',
#  'WS',
#  'WS_per_48',
#  'BPM',
#  'VORP']

# %%
draft_df.set_index("Player", inplace=True)
draft_df.head()
# Out:
#                  Draft_Yr  Pk   Tm                          College  Yrs    G  \
# Player
# Anthony Bennett      2013   1  CLE  University of Nevada, Las Vegas    4  151
# Victor Oladipo       2013   2  ORL               Indiana University    6  369
# Otto Porter          2013   3  WAS            Georgetown University    6  345
# Cody Zeller          2013   4  CHA               Indiana University    6  315
# Alex Len             2013   5  PHO           University of Maryland    6  337
#
#                     MP   PTS   TRB   AST  ...   3P_Perc  FT_Perc  MP_per_G  \
# Player                                    ...
# Anthony Bennett   1905   658   472    77  ...     0.261    0.670      1905
# Victor Oladipo   12303  6419  1674  1412  ...     0.354    0.797     12303
# Otto Porter       9123  3623  1687   473  ...     0.404    0.789      9123
# Cody Zeller       7097  2496  1771   398  ...     0.294    0.734      7097
# ...

# %%
training_draft = draft_df.loc[['Anthony Bennett', 'Victor Oladipo', 'Giannis Antetokounmpo', 'Ben McLemore', 'Andrew Wiggins', 'Joel Embiid', 'Nik Stauskas', 'Spencer Dinwiddie', 'Karl-Anthony Towns', 'Jahlil Okafor', 'Emmanuel Mudiay', 'Josh Richardson', 'Ben Simmons', 'Dragan Bender', 'Kris Dunn', 'Malcolm Brogdon', 'Lonzo Ball', 'Jayson Tatum', 'Frank Ntilikina', 'Donovan Mitchell', 'Jordan Bell']]
training_draft.head()
# Out:
#                        Draft_Yr  Pk   Tm                          College  \
# Player
# Anthony Bennett            2013   1  CLE  University of Nevada, Las Vegas
# Victor Oladipo             2013   2  ORL               Indiana University
# Giannis Antetokounmpo      2013  15  MIL                              NaN
# Ben McLemore               2013   7  SAC             University of Kansas
# Andrew Wiggins             2014   1  CLE             University of Kansas
#
#                        Yrs    G     MP   PTS   TRB   AST  ...   3P_Perc  \
# Player                                                    ...
# Anthony Bennett          4  151   1905   658   472    77  ...     0.261
# Victor Oladipo           6  369  12303  6419  1674  1412  ...     0.354
# Giannis Antetokounmpo    6  395  12929  6802  2979  1510  ...     0.280
# Ben McLemore             6  350   8573  3167   892   403  ...     0.351
# Andrew Wiggins           5  330  11942  6508  1363   690  ...     0.330
#
# ...

# %%
advanced_df.set_index("Player", inplace=True)
advanced_df.head()
# Out:
#                NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc   3PAr  \
# Player
# Jeff Adrien          2013  PF   26  CHA  52   713  13.4    0.493  0.012
# Arron Afflalo        2013  SF   27  ORL  64  2307  13.0    0.527  0.265
# Josh Akognon         2013  PG   26  DAL   3     9  15.3    0.625  0.500
# Cole Aldrich         2013   C   24  TOT  45   388  11.1    0.563  0.000
# Cole Aldrich         2013   C   24  HOU  30   213   7.3    0.532  0.000
#
#                  FTr  ...   TOV_Perc  USG_Perc  OWS  DWS   WS  WS_per_48  \
# Player                ...
# Jeff Adrien    0.595  ...       13.1      15.6  0.5  0.4  1.0      0.064
# Arron Afflalo  0.246  ...       12.1      22.5  1.5  0.5  2.0      0.042
# Josh Akognon   0.000  ...        0.0      20.3  0.0  0.0  0.0      0.196
# Cole Aldrich   0.250  ...       20.6      12.7  0.1  0.4  0.6      0.070
# Cole Aldrich   0.209  ...       23.0      12.5 -0.1  0.3  0.2      0.038
#
#                OBPM  DBPM  BPM  VORP
# Player
# ...

# %%
training_advanced = advanced_df.loc[['Anthony Bennett', 'Victor Oladipo', 'Giannis Antetokounmpo', 'Ben McLemore', 'Michael Carter-Williams', 'Rudy Gobert', 'Andrew Wiggins', 'Joel Embiid', 'Nik Stauskas', 'Spencer Dinwiddie', 'Zach LaVine', 'Karl-Anthony Towns', 'Jahlil Okafor', 'Emmanuel Mudiay', 'Josh Richardson', 'Ben Simmons', 'Dragan Bender', 'Kris Dunn', 'Malcolm Brogdon', 'Jaylen Brown', 'Lonzo Ball', 'Jayson Tatum', 'Frank Ntilikina', 'Donovan Mitchell', 'Jordan Bell']]
training_advanced.head()
# Out:
#                  NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc   3PAr  \
# Player
# Anthony Bennett        2014  PF   20  CLE  52   663   6.9    0.425  0.236
# Anthony Bennett        2015  PF   21  MIN  57   894  11.4    0.458  0.077
# Anthony Bennett        2016  PF   22  TOR  19    84  10.4    0.446  0.519
# Anthony Bennett        2017  PF   23  BRK  23   264  14.7    0.533  0.522
# Victor Oladipo         2014  PG   21  ORL  80  2487  13.6    0.514  0.241
#
#                    FTr  ...   TOV_Perc  USG_Perc  OWS  DWS   WS  WS_per_48  \
# Player                  ...
# Anthony Bennett  0.307  ...       15.5      20.3 -1.1  0.7 -0.4     -0.028
# Anthony Bennett  0.215  ...       10.0      17.8 -0.1  0.4  0.3      0.017
# Anthony Bennett  0.370  ...       11.3      19.2  0.0  0.1  0.1      0.054
# Anthony Bennett  0.391  ...       10.0      19.4  0.3  0.2  0.5      0.090
# Victor Oladipo   0.340  ...       19.2      24.4 -1.4  2.8  1.3      0.026
#
# ...

# %%
training_advanced = training_advanced[~training_advanced.index.duplicated(keep='first')]
training_advanced
# Out:
#                          NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Anthony Bennett                2014  PF   20  CLE  52   663   6.9    0.425
# Victor Oladipo                 2014  PG   21  ORL  80  2487  13.6    0.514
# Giannis Antetokounmpo          2014  SF   19  MIL  77  1897  10.8    0.518
# Ben McLemore                   2014  SG   20  SAC  82  2187   7.7    0.485
# Michael Carter-Williams        2014  PG   22  PHI  70  2414  15.5    0.480
# Rudy Gobert                    2014   C   21  UTA  45   434  12.9    0.507
# Andrew Wiggins                 2015  SF   19  MIN  82  2969  13.9    0.517
# Joel Embiid                    2017   C   22  PHI  31   786  24.1    0.584
# Nik Stauskas                   2015  SG   21  SAC  73  1127   7.5    0.492
# Spencer Dinwiddie              2015  PG   21  DET  34   455  10.2    0.394
# Zach LaVine                    2015  PG   19  MIN  77  1902  11.3    0.515
# ...

# %%
training_advanced.to_csv("training_advanced_data.csv")

# %%
alldraft = advanced_df.loc[advanced_df.index.isin(draft_df.index)]
alldraft
# Out:
#                           NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Marcus Thornton                 2013  SG   25  SAC  72  1726  16.3    0.552
# Steven Adams                    2014   C   20  OKC  81  1197  11.2    0.541
# Giannis Antetokounmpo           2014  SF   19  MIL  77  1897  10.8    0.518
# Anthony Bennett                 2014  PF   20  CLE  52   663   6.9    0.425
# Lorenzo Brown                   2014  PG   23  PHI  26   224   8.2    0.349
# Reggie Bullock                  2014  SF   22  LAC  43   395   6.7    0.460
# Trey Burke                      2014  PG   21  UTA  70  2262  12.6    0.473
# Kentavious Caldwell-Pope        2014  SG   20  DET  80  1583   9.4    0.483
# Isaiah Canaan                   2014  PG   22  HOU  22   252   9.5    0.506
# Michael Carter-Williams         2014  PG   22  PHI  70  2414  15.5    0.480
# Allen Crabbe                    2014  SG   21  POR  15   100   7.7    0.475
# ...

# %%
draft_advanced = alldraft[~alldraft.index.duplicated(keep='first')]
draft_advanced
# Out:
#                           NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Marcus Thornton                 2013  SG   25  SAC  72  1726  16.3    0.552
# Steven Adams                    2014   C   20  OKC  81  1197  11.2    0.541
# Giannis Antetokounmpo           2014  SF   19  MIL  77  1897  10.8    0.518
# Anthony Bennett                 2014  PF   20  CLE  52   663   6.9    0.425
# Lorenzo Brown                   2014  PG   23  PHI  26   224   8.2    0.349
# Reggie Bullock                  2014  SF   22  LAC  43   395   6.7    0.460
# Trey Burke                      2014  PG   21  UTA  70  2262  12.6    0.473
# Kentavious Caldwell-Pope        2014  SG   20  DET  80  1583   9.4    0.483
# Isaiah Canaan                   2014  PG   22  HOU  22   252   9.5    0.506
# Michael Carter-Williams         2014  PG   22  PHI  70  2414  15.5    0.480
# Allen Crabbe                    2014  SG   21  POR  15   100   7.7    0.475
# ...

# %%
draft_advanced = draft_advanced.iloc[1:]
draft_advanced
# Out:
#                           NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Steven Adams                    2014   C   20  OKC  81  1197  11.2    0.541
# Giannis Antetokounmpo           2014  SF   19  MIL  77  1897  10.8    0.518
# Anthony Bennett                 2014  PF   20  CLE  52   663   6.9    0.425
# Lorenzo Brown                   2014  PG   23  PHI  26   224   8.2    0.349
# Reggie Bullock                  2014  SF   22  LAC  43   395   6.7    0.460
# Trey Burke                      2014  PG   21  UTA  70  2262  12.6    0.473
# Kentavious Caldwell-Pope        2014  SG   20  DET  80  1583   9.4    0.483
# Isaiah Canaan                   2014  PG   22  HOU  22   252   9.5    0.506
# Michael Carter-Williams         2014  PG   22  PHI  70  2414  15.5    0.480
# Allen Crabbe                    2014  SG   21  POR  15   100   7.7    0.475
# Gorgui Dieng                    2014   C   24  MIN  60   818  16.5    0.534
# ...

# %%
# draft_advanced.to_csv("draft_advanced_data.csv")

# %%
draft_advanced.sort_values('BPM')
# Out:
#                          NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Ben Bentil                     2017  PF   21  DAL   3    10 -17.6    0.000
# Diamond Stone                  2017   C   19  LAC   7    24  -1.2    0.339
# Bruno Caboclo                  2015  SF   19  TOR   8    23  -1.8    0.417
# Julius Randle                  2015  PF   20  LAL   1    14  -7.5    0.258
# Georges Niang                  2017  PF   23  IND  23    93   0.1    0.285
# Nemanja Nedovic                2014  SG   22  GSW  24   142  -1.7    0.306
# Michael Gbinije                2017  SG   24  DET   9    32  -2.1    0.184
# Lucas Nogueira                 2015   C   22  TOR   6    23   5.2    0.307
# Tony Bradley                   2018   C   20  UTA   9    29   9.5    0.337
# Damian Jones                   2017   C   21  GSW  10    85   5.3    0.466
# Kevon Looney                   2016  PF   19  GSW   5    21  18.6    0.643
# ...

# %%
draft_advanced["WAR"] = (draft_advanced["VORP"]*2.7)
draft_advanced
# Out:
# C:\Users\pinkp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                           NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Steven Adams                    2014   C   20  OKC  81  1197  11.2    0.541
# Giannis Antetokounmpo           2014  SF   19  MIL  77  1897  10.8    0.518
# Anthony Bennett                 2014  PF   20  CLE  52   663   6.9    0.425
# Lorenzo Brown                   2014  PG   23  PHI  26   224   8.2    0.349
# Reggie Bullock                  2014  SF   22  LAC  43   395   6.7    0.460
# Trey Burke                      2014  PG   21  UTA  70  2262  12.6    0.473
# ...

# %%
draft_advanced.sort_values('WAR')
# Out:
#                          NBA_Season Pos  Age   Tm   G    MP   PER  TS_Perc  \
# Player
# Isaiah Whitehead               2017  PG   21  BRK  73  1643   7.6    0.487
# Zach LaVine                    2015  PG   19  MIN  77  1902  11.3    0.515
# De'Aaron Fox                   2018  PG   20  SAC  73  2026  11.2    0.478
# Emmanuel Mudiay                2016  PG   19  DEN  68  2068   9.9    0.437
# Domantas Sabonis               2017  PF   20  OKC  81  1632   6.9    0.469
# Brandon Ingram                 2017  SF   19  LAL  79  2279   8.5    0.474
# Josh Jackson                   2018  SF   20  PHO  77  1959  11.8    0.480
# Semaj Christon                 2017  PG   24  OKC  64   973   5.7    0.387
# Dennis Schroder                2014  PG   20  ATL  49   641   5.8    0.442
# Rashad Vaughn                  2016  SG   19  MIL  70  1001   4.2    0.398
# Anthony Bennett                2014  PF   20  CLE  52   663   6.9    0.425
# ...

# %%
draft_advanced.to_csv("draft_advanced_data_war.csv")
